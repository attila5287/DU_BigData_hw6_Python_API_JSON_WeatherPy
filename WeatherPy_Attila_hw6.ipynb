# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
# generate random numbers for cities
import numpy as np
import requests
import urllib
# API key
import api_keys
# print todays date on final output charts
import time
# return city with zip info to be obtained by lat/long random numbers
from citipy import citipy
# print on blank csv file-created previously
output_data_file = "output_data/cities.csv"
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# store lat/long and cities on lists
rand_latlong= []
cities = []

# random numpy array of 1,500 lat-long combo
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
# zip object in order to iterate two variables together
rand_latlong= zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for LatLong in rand_latlong:
    city = citipy.nearest_city(LatLong[0], LatLong[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
city_count = len(cities)
if city_count >=500:
    print(str(city_count) + " cities: sufficient")
else:
        print(str(city_count) + " cities not sufficient")
# Out:
# 604 cities: sufficient

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key
# gathering URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# to store city data
city_data = []

# Print to logger
print("---Loading Data for---(%s)" % time.strftime("%x"))
print("----------------------------------")

# Create counters
record_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    city_url = url + "&q=" + urllib.request.pathname2url(city)
    print("Processing Record %s of %s | %s" % (record_count, city_count, city))
    print(city_url)
    record_count += 1
    try:
        # Parse the JSON and retrieve data
        openweather= requests.get(city_url).json()
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": openweather["coord"]["lat"], 
                          "Lng": openweather["coord"]["lon"],
                          "Max Temp": openweather["main"]["temp_max"],
                          "Humidity": openweather["main"]["humidity"],
                          "Cloudiness": openweather["clouds"]["all"],
                          "Wind Speed": openweather["wind"]["speed"],
                          "Country": openweather["sys"]["country"],
                          "Date": openweather["dt"]})

    # If an error is experienced, skip the city
    except:
        print("No data found for requested city...\nSkipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("---Data Retrieval Complete---")
print("-----------------------------")
# Out:
# ---Loading Data for---(10/04/18)
# ----------------------------------
# Processing Record 1 of 604 | gotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gotsu
# Processing Record 2 of 604 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=grand%20river%20south%20east
# No data found for requested city...
# Skipping...
# Processing Record 3 of 604 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=butaritari
# Processing Record 4 of 604 | kantabanji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kantabanji
# Processing Record 5 of 604 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tsihombe
# No data found for requested city...
# Skipping...
# Processing Record 6 of 604 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=alofi
# Processing Record 7 of 604 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=qaanaaq
# Processing Record 8 of 604 | kuminskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kuminskiy
# Processing Record 9 of 604 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=punta%20arenas
# Processing Record 10 of 604 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=berdigestyakh
# Processing Record 11 of 604 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rikitea
# Processing Record 12 of 604 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=talnakh
# Processing Record 13 of 604 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hermanus
# Processing Record 14 of 604 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lata
# Processing Record 15 of 604 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lompoc
# Processing Record 16 of 604 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=atuona
# Processing Record 17 of 604 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=puerto%20ayora
# Processing Record 18 of 604 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=severo-kurilsk
# Processing Record 19 of 604 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bluff
# Processing Record 20 of 604 | we
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=we
# No data found for requested city...
# Skipping...
# Processing Record 21 of 604 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=arlit
# Processing Record 22 of 604 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=berlevag
# Processing Record 23 of 604 | dali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=dali
# Processing Record 24 of 604 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vaini
# Processing Record 25 of 604 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20quintin
# Processing Record 26 of 604 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port%20alfred
# Processing Record 27 of 604 | pingshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pingshan
# Processing Record 28 of 604 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=dikson
# Processing Record 29 of 604 | norsup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=norsup
# Processing Record 30 of 604 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=codrington
# Processing Record 31 of 604 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mackay
# Processing Record 32 of 604 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hofn
# Processing Record 33 of 604 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=albany
# Processing Record 34 of 604 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=upernavik
# Processing Record 35 of 604 | oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=oksfjord
# Processing Record 36 of 604 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=guerrero%20negro
# Processing Record 37 of 604 | diego de almagro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=diego%20de%20almagro
# Processing Record 38 of 604 | altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=altamont
# Processing Record 39 of 604 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=clyde%20river
# Processing Record 40 of 604 | harlingen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=harlingen
# Processing Record 41 of 604 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ilulissat
# Processing Record 42 of 604 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saint%20george
# Processing Record 43 of 604 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=harper
# Processing Record 44 of 604 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=busselton
# Processing Record 45 of 604 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=salalah
# Processing Record 46 of 604 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=new%20norfolk
# Processing Record 47 of 604 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=shache
# Processing Record 48 of 604 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ushuaia
# Processing Record 49 of 604 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port%20macquarie
# Processing Record 50 of 604 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=brae
# Processing Record 51 of 604 | karaul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=karaul
# No data found for requested city...
# Skipping...
# Processing Record 52 of 604 | carlos chagas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=carlos%20chagas
# Processing Record 53 of 604 | ivolginsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ivolginsk
# Processing Record 54 of 604 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saint-philippe
# Processing Record 55 of 604 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sokoni
# Processing Record 56 of 604 | roros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=roros
# Processing Record 57 of 604 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=isangel
# Processing Record 58 of 604 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nanortalik
# Processing Record 59 of 604 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=chuy
# Processing Record 60 of 604 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yumen
# Processing Record 61 of 604 | namli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=namli
# Processing Record 62 of 604 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=avarua
# Processing Record 63 of 604 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kaeo
# Processing Record 64 of 604 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=illoqqortoormiut
# No data found for requested city...
# Skipping...
# Processing Record 65 of 604 | luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=luau
# Processing Record 66 of 604 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hobart
# Processing Record 67 of 604 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kodiak
# Processing Record 68 of 604 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=provideniya
# Processing Record 69 of 604 | grimbergen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=grimbergen
# Processing Record 70 of 604 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=victoria
# Processing Record 71 of 604 | varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=varhaug
# Processing Record 72 of 604 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=geraldton
# Processing Record 73 of 604 | innisfail
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=innisfail
# Processing Record 74 of 604 | briancon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=briancon
# Processing Record 75 of 604 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=aksu
# Processing Record 76 of 604 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=jamestown
# Processing Record 77 of 604 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tasiilaq
# Processing Record 78 of 604 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kapaa
# Processing Record 79 of 604 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port%20elizabeth
# Processing Record 80 of 604 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=taolanaro
# No data found for requested city...
# Skipping...
# Processing Record 81 of 604 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cape%20town
# Processing Record 82 of 604 | kargasok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kargasok
# Processing Record 83 of 604 | tsienyane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tsienyane
# No data found for requested city...
# Skipping...
# Processing Record 84 of 604 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tuktoyaktuk
# Processing Record 85 of 604 | kalawit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kalawit
# Processing Record 86 of 604 | santa helena de goias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=santa%20helena%20de%20goias
# Processing Record 87 of 604 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=longyearbyen
# Processing Record 88 of 604 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=faya
# Processing Record 89 of 604 | korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=korem
# Processing Record 90 of 604 | naftah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=naftah
# No data found for requested city...
# Skipping...
# Processing Record 91 of 604 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tutoia
# Processing Record 92 of 604 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=airai
# Processing Record 93 of 604 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mys%20shmidta
# No data found for requested city...
# Skipping...
# Processing Record 94 of 604 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bubaque
# Processing Record 95 of 604 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=faanui
# Processing Record 96 of 604 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=karratha
# Processing Record 97 of 604 | jawhar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=jawhar
# Processing Record 98 of 604 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=buchanan
# Processing Record 99 of 604 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nemuro
# Processing Record 100 of 604 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hithadhoo
# Processing Record 101 of 604 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=barrow
# Processing Record 102 of 604 | agirish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=agirish
# Processing Record 103 of 604 | poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=poum
# Processing Record 104 of 604 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bengkulu
# No data found for requested city...
# Skipping...
# Processing Record 105 of 604 | beckley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=beckley
# Processing Record 106 of 604 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=klaksvik
# Processing Record 107 of 604 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=zyryanka
# Processing Record 108 of 604 | kambove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kambove
# Processing Record 109 of 604 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mataura
# Processing Record 110 of 604 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lorengau
# Processing Record 111 of 604 | omboue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=omboue
# Processing Record 112 of 604 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=narsaq
# Processing Record 113 of 604 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=acarau
# No data found for requested city...
# Skipping...
# Processing Record 114 of 604 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mahebourg
# Processing Record 115 of 604 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pevek
# Processing Record 116 of 604 | stoyba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=stoyba
# No data found for requested city...
# Skipping...
# Processing Record 117 of 604 | normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=normandin
# Processing Record 118 of 604 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ancud
# Processing Record 119 of 604 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=grindavik
# Processing Record 120 of 604 | rafraf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rafraf
# Processing Record 121 of 604 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nikolskoye
# Processing Record 122 of 604 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=grand%20gaube
# Processing Record 123 of 604 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bambous%20virieux
# Processing Record 124 of 604 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lebu
# Processing Record 125 of 604 | gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gwadar
# Processing Record 126 of 604 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=okha
# Processing Record 127 of 604 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=barbar
# No data found for requested city...
# Skipping...
# Processing Record 128 of 604 | manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=manicore
# Processing Record 129 of 604 | jurado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=jurado
# No data found for requested city...
# Skipping...
# Processing Record 130 of 604 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vanavara
# Processing Record 131 of 604 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vao
# Processing Record 132 of 604 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=fairbanks
# Processing Record 133 of 604 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=iracoubo
# Processing Record 134 of 604 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bredasdorp
# Processing Record 135 of 604 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=souillac
# Processing Record 136 of 604 | aba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=aba
# Processing Record 137 of 604 | santa vitoria do palmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=santa%20vitoria%20do%20palmar
# Processing Record 138 of 604 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=esperance
# Processing Record 139 of 604 | san ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20ramon
# Processing Record 140 of 604 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kahului
# Processing Record 141 of 604 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yellowknife
# Processing Record 142 of 604 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=constitucion
# Processing Record 143 of 604 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=belushya%20guba
# No data found for requested city...
# Skipping...
# Processing Record 144 of 604 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=svetlogorsk
# Processing Record 145 of 604 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lolua
# No data found for requested city...
# Skipping...
# Processing Record 146 of 604 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=la%20ronge
# Processing Record 147 of 604 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=louisbourg
# No data found for requested city...
# Skipping...
# Processing Record 148 of 604 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=axim
# Processing Record 149 of 604 | muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=muravlenko
# Processing Record 150 of 604 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=fort%20nelson
# Processing Record 151 of 604 | kuruman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kuruman
# Processing Record 152 of 604 | nyurba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nyurba
# Processing Record 153 of 604 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hobyo
# Processing Record 154 of 604 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vila
# Processing Record 155 of 604 | nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nador
# Processing Record 156 of 604 | rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rivadavia
# Processing Record 157 of 604 | port-de-paix
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port-de-paix
# No data found for requested city...
# Skipping...
# Processing Record 158 of 604 | tulum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tulum
# Processing Record 159 of 604 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=inirida
# Processing Record 160 of 604 | kangaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kangaba
# Processing Record 161 of 604 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=meulaboh
# Processing Record 162 of 604 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tumannyy
# No data found for requested city...
# Skipping...
# Processing Record 163 of 604 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hambantota
# Processing Record 164 of 604 | mananara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mananara
# No data found for requested city...
# Skipping...
# Processing Record 165 of 604 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vaitupu
# No data found for requested city...
# Skipping...
# Processing Record 166 of 604 | kencong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kencong
# Processing Record 167 of 604 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mar%20del%20plata
# Processing Record 168 of 604 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ostrovnoy
# Processing Record 169 of 604 | lumeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lumeje
# Processing Record 170 of 604 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=oranjemund
# Processing Record 171 of 604 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hilo
# Processing Record 172 of 604 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tabou
# Processing Record 173 of 604 | oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=oistins
# Processing Record 174 of 604 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=beyneu
# Processing Record 175 of 604 | newcastle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=newcastle
# Processing Record 176 of 604 | mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mackenzie
# Processing Record 177 of 604 | cururupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cururupu
# Processing Record 178 of 604 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port%20hardy
# Processing Record 179 of 604 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=am%20timan
# Processing Record 180 of 604 | artyom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=artyom
# Processing Record 181 of 604 | belle fourche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=belle%20fourche
# Processing Record 182 of 604 | marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=marsaxlokk
# Processing Record 183 of 604 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hirara
# Processing Record 184 of 604 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=los%20llanos%20de%20aridane
# Processing Record 185 of 604 | nueva londres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nueva%20londres
# Processing Record 186 of 604 | kozachi laheri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kozachi%20laheri
# Processing Record 187 of 604 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saint-augustin
# Processing Record 188 of 604 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=barentsburg
# No data found for requested city...
# Skipping...
# Processing Record 189 of 604 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=khatanga
# Processing Record 190 of 604 | talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=talara
# Processing Record 191 of 604 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sentyabrskiy
# No data found for requested city...
# Skipping...
# Processing Record 192 of 604 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=moron
# Processing Record 193 of 604 | sao jose da coroa grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sao%20jose%20da%20coroa%20grande
# Processing Record 194 of 604 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=westport
# Processing Record 195 of 604 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ambilobe
# Processing Record 196 of 604 | wadena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=wadena
# Processing Record 197 of 604 | meiganga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=meiganga
# Processing Record 198 of 604 | zhifang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=zhifang
# Processing Record 199 of 604 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saldanha
# Processing Record 200 of 604 | mitu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mitu
# Processing Record 201 of 604 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=beloha
# Processing Record 202 of 604 | finschhafen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=finschhafen
# Processing Record 203 of 604 | petropavlovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=petropavlovskoye
# Processing Record 204 of 604 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cherskiy
# Processing Record 205 of 604 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=labuhan
# Processing Record 206 of 604 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=samusu
# No data found for requested city...
# Skipping...
# Processing Record 207 of 604 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=attawapiskat
# No data found for requested city...
# Skipping...
# Processing Record 208 of 604 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nizhniy%20kuranakh
# Processing Record 209 of 604 | taguatinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=taguatinga
# Processing Record 210 of 604 | opunake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=opunake
# Processing Record 211 of 604 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=leningradskiy
# Processing Record 212 of 604 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=valparaiso
# Processing Record 213 of 604 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=iqaluit
# Processing Record 214 of 604 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cockburn%20town
# Processing Record 215 of 604 | ust-karsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ust-karsk
# Processing Record 216 of 604 | harsin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=harsin
# Processing Record 217 of 604 | zhanaozen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=zhanaozen
# Processing Record 218 of 604 | copiapo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=copiapo
# Processing Record 219 of 604 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20ignacio
# Processing Record 220 of 604 | wenceslau braz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=wenceslau%20braz
# Processing Record 221 of 604 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=castro
# Processing Record 222 of 604 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sisimiut
# Processing Record 223 of 604 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saskylakh
# Processing Record 224 of 604 | ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ucluelet
# Processing Record 225 of 604 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=thompson
# Processing Record 226 of 604 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20carlos%20de%20bariloche
# Processing Record 227 of 604 | tidore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tidore
# No data found for requested city...
# Skipping...
# Processing Record 228 of 604 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pemangkat
# No data found for requested city...
# Skipping...
# Processing Record 229 of 604 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=georgetown
# Processing Record 230 of 604 | karangampel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=karangampel
# Processing Record 231 of 604 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ponta%20do%20sol
# Processing Record 232 of 604 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lufilufi
# Processing Record 233 of 604 | santa eulalia del rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=santa%20eulalia%20del%20rio
# No data found for requested city...
# Skipping...
# Processing Record 234 of 604 | pindiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pindiga
# Processing Record 235 of 604 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=broome
# Processing Record 236 of 604 | stekolnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=stekolnyy
# No data found for requested city...
# Skipping...
# Processing Record 237 of 604 | hudiksvall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hudiksvall
# Processing Record 238 of 604 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sao%20joao%20da%20barra
# Processing Record 239 of 604 | tamiahua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tamiahua
# Processing Record 240 of 604 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kruisfontein
# Processing Record 241 of 604 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=carnarvon
# Processing Record 242 of 604 | shahrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=shahrud
# Processing Record 243 of 604 | george town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=george%20town
# Processing Record 244 of 604 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=maceio
# Processing Record 245 of 604 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yenagoa
# Processing Record 246 of 604 | betanzos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=betanzos
# Processing Record 247 of 604 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rungata
# No data found for requested city...
# Skipping...
# Processing Record 248 of 604 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20patricio
# Processing Record 249 of 604 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=amderma
# No data found for requested city...
# Skipping...
# Processing Record 250 of 604 | ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ornskoldsvik
# Processing Record 251 of 604 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kavieng
# Processing Record 252 of 604 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nizhneyansk
# No data found for requested city...
# Skipping...
# Processing Record 253 of 604 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mehamn
# Processing Record 254 of 604 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=chifeng
# Processing Record 255 of 604 | pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pimenta%20bueno
# Processing Record 256 of 604 | rosarito
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rosarito
# Processing Record 257 of 604 | uyovu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=uyovu
# Processing Record 258 of 604 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=camacha
# Processing Record 259 of 604 | kitimat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kitimat
# Processing Record 260 of 604 | kiknur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kiknur
# Processing Record 261 of 604 | kassala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kassala
# Processing Record 262 of 604 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=caravelas
# Processing Record 263 of 604 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port-gentil
# Processing Record 264 of 604 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tiksi
# Processing Record 265 of 604 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=touros
# Processing Record 266 of 604 | karaikkudi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=karaikkudi
# Processing Record 267 of 604 | antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=antofagasta
# Processing Record 268 of 604 | eydhafushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=eydhafushi
# Processing Record 269 of 604 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=arraial%20do%20cabo
# Processing Record 270 of 604 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sorvag
# No data found for requested city...
# Skipping...
# Processing Record 271 of 604 | armidale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=armidale
# Processing Record 272 of 604 | nalut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nalut
# Processing Record 273 of 604 | mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mogadishu
# Processing Record 274 of 604 | maraa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=maraa
# Processing Record 275 of 604 | visby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=visby
# Processing Record 276 of 604 | mizan teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mizan%20teferi
# Processing Record 277 of 604 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=araouane
# Processing Record 278 of 604 | freeport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=freeport
# Processing Record 279 of 604 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=saint-francois
# Processing Record 280 of 604 | cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cooma
# Processing Record 281 of 604 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kavaratti
# Processing Record 282 of 604 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=luderitz
# Processing Record 283 of 604 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pacific%20grove
# Processing Record 284 of 604 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=east%20london
# Processing Record 285 of 604 | ullapool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ullapool
# Processing Record 286 of 604 | puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=puri
# Processing Record 287 of 604 | gumdag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gumdag
# Processing Record 288 of 604 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kysyl-syr
# Processing Record 289 of 604 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rio%20gallegos
# Processing Record 290 of 604 | orzhytsya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=orzhytsya
# Processing Record 291 of 604 | lernapat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lernapat
# Processing Record 292 of 604 | chilca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=chilca
# Processing Record 293 of 604 | nueve de julio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nueve%20de%20julio
# Processing Record 294 of 604 | noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=noumea
# Processing Record 295 of 604 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=komsomolskiy
# Processing Record 296 of 604 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=banda%20aceh
# Processing Record 297 of 604 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=buala
# Processing Record 298 of 604 | spasskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=spasskoye
# Processing Record 299 of 604 | peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=peniche
# Processing Record 300 of 604 | formoso do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=formoso%20do%20araguaia
# No data found for requested city...
# Skipping...
# Processing Record 301 of 604 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sistranda
# Processing Record 302 of 604 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=chokurdakh
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=high%20level
# Processing Record 505 of 604 | mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mujiayingzi
# Processing Record 506 of 604 | linxia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=linxia
# Processing Record 507 of 604 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cabo%20san%20lucas
# Processing Record 508 of 604 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=cidreira
# Processing Record 509 of 604 | xaltianguis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=xaltianguis
# Processing Record 510 of 604 | amtala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=amtala
# Processing Record 511 of 604 | batagay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=batagay
# Processing Record 512 of 604 | kyra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kyra
# No data found for requested city...
# Skipping...
# Processing Record 513 of 604 | koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=koumac
# Processing Record 514 of 604 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bethel
# Processing Record 515 of 604 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=jumla
# Processing Record 516 of 604 | simplicio mendes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=simplicio%20mendes
# Processing Record 517 of 604 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=prince%20rupert
# Processing Record 518 of 604 | noyabrsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=noyabrsk
# Processing Record 519 of 604 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yar-sale
# Processing Record 520 of 604 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=champerico
# Processing Record 521 of 604 | pokaran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=pokaran
# Processing Record 522 of 604 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mbandaka
# Processing Record 523 of 604 | gucheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gucheng
# Processing Record 524 of 604 | bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bairiki
# No data found for requested city...
# Skipping...
# Processing Record 525 of 604 | kodinar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kodinar
# Processing Record 526 of 604 | korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=korla
# No data found for requested city...
# Skipping...
# Processing Record 527 of 604 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lahaina
# Processing Record 528 of 604 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=olinda
# Processing Record 529 of 604 | mora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mora
# Processing Record 530 of 604 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kaitangata
# Processing Record 531 of 604 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=byron%20bay
# Processing Record 532 of 604 | esil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=esil
# Processing Record 533 of 604 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=aykhal
# Processing Record 534 of 604 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vostok
# Processing Record 535 of 604 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=havelock
# Processing Record 536 of 604 | miracema do tocantins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=miracema%20do%20tocantins
# Processing Record 537 of 604 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=coquimbo
# Processing Record 538 of 604 | sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sumbe
# Processing Record 539 of 604 | hokitika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=hokitika
# Processing Record 540 of 604 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nishihara
# Processing Record 541 of 604 | sironj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sironj
# Processing Record 542 of 604 | ouargaye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=ouargaye
# Processing Record 543 of 604 | magnor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=magnor
# Processing Record 544 of 604 | rtishchevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rtishchevo
# Processing Record 545 of 604 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=dunedin
# Processing Record 546 of 604 | carroll
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=carroll
# Processing Record 547 of 604 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=takoradi
# Processing Record 548 of 604 | picayune
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=picayune
# Processing Record 549 of 604 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tommot
# Processing Record 550 of 604 | shimanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=shimanovsk
# Processing Record 551 of 604 | zabol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=zabol
# Processing Record 552 of 604 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=namibe
# Processing Record 553 of 604 | kampene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kampene
# Processing Record 554 of 604 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=biak
# Processing Record 555 of 604 | itupiranga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=itupiranga
# Processing Record 556 of 604 | prestea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=prestea
# Processing Record 557 of 604 | katsina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=katsina
# Processing Record 558 of 604 | sao raimundo nonato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sao%20raimundo%20nonato
# No data found for requested city...
# Skipping...
# Processing Record 559 of 604 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=te%20anau
# Processing Record 560 of 604 | yanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yanan
# No data found for requested city...
# Skipping...
# Processing Record 561 of 604 | gangotri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gangotri
# No data found for requested city...
# Skipping...
# Processing Record 562 of 604 | lokosovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=lokosovo
# Processing Record 563 of 604 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mecca
# Processing Record 564 of 604 | makaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=makaha
# Processing Record 565 of 604 | syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=syracuse
# Processing Record 566 of 604 | barinitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=barinitas
# Processing Record 567 of 604 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=port%20blair
# Processing Record 568 of 604 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=broken%20hill
# Processing Record 569 of 604 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=skalistyy
# No data found for requested city...
# Skipping...
# Processing Record 570 of 604 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=stornoway
# No data found for requested city...
# Skipping...
# Processing Record 571 of 604 | mwene-ditu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mwene-ditu
# Processing Record 572 of 604 | alugan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=alugan
# Processing Record 573 of 604 | guadalajara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=guadalajara
# Processing Record 574 of 604 | billings
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=billings
# Processing Record 575 of 604 | bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bilibino
# Processing Record 576 of 604 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=upata
# Processing Record 577 of 604 | sioux lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sioux%20lookout
# Processing Record 578 of 604 | denison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=denison
# Processing Record 579 of 604 | nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nioro
# Processing Record 580 of 604 | haibowan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=haibowan
# No data found for requested city...
# Skipping...
# Processing Record 581 of 604 | gaurela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=gaurela
# Processing Record 582 of 604 | priverno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=priverno
# Processing Record 583 of 604 | liverpool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=liverpool
# Processing Record 584 of 604 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=erenhot
# Processing Record 585 of 604 | sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=sakaiminato
# Processing Record 586 of 604 | basse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=basse
# Processing Record 587 of 604 | miranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=miranda
# Processing Record 588 of 604 | villa de san francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=villa%20de%20san%20francisco
# Processing Record 589 of 604 | kingman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=kingman
# Processing Record 590 of 604 | vilhena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=vilhena
# Processing Record 591 of 604 | bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=bara
# Processing Record 592 of 604 | mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=mangan
# Processing Record 593 of 604 | xintai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=xintai
# Processing Record 594 of 604 | revelstoke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=revelstoke
# Processing Record 595 of 604 | angoram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=angoram
# Processing Record 596 of 604 | tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tarko-sale
# Processing Record 597 of 604 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=havre-saint-pierre
# Processing Record 598 of 604 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=nome
# Processing Record 599 of 604 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=rocha
# Processing Record 600 of 604 | beysehir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=beysehir
# Processing Record 601 of 604 | el mahalla el kubra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=el%20mahalla%20el%20kubra
# No data found for requested city...
# Skipping...
# Processing Record 602 of 604 | tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=tahe
# Processing Record 603 of 604 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=san%20policarpo
# Processing Record 604 of 604 | yichang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d5b5a0725a0077b3ef37062a038d5b29&q=yichang
# -----------------------------
# ---Data Retrieval Complete---
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)
# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")
# unique cities for city record count
record_count = len(city_data_pd['City'].unique())
print("Number of records found: %s (unique cities)" %(record_count))
# Out:
# Number of records found: 536 (unique cities)

# %%
# # objective is to build a series of scatter plots to showcase the following relationships:
lat_axis = city_data_pd['Lat']
# # Temperature (F) vs. Latitude
# # Humidity (%) vs. Latitude
# # Cloudiness (%) vs. Latitude
# # Wind Speed (mph) vs. Latitude

# %%
# keep lat_axis fixed for every iteration and iterate through all other axis arrays
ax_list = ['Max Temp','Humidity', 'Cloudiness', 'Wind Speed']
# create an array for different colors on each plot
color_list = ['b', 'r' , 'g' , 'y']
# scatter plots with todays date, then save on output_data output_data folder and print messages along 
for axis in ax_list:
        plt.figure(figsize=(15,6))
        plt.title(axis + " vs Lattitude (%s)" % time.strftime("%x"))
        print(axis + " vs Lat. plotting...")
        plt.scatter(lat_axis, city_data_pd[axis], marker="o", facecolors= color_list[ax_list.index(axis)], edgecolors="black", alpha=0.90)
        plt.xlabel('Lattitude')
        plt.ylabel(axis)
        plt.grid()
        plt.savefig('output_data/Lattitude_vs_'+axis)
        plt.show()
        print("             *" + axis + " vs Lat. saved as ..."+'output_data/Lattitude_vs_'+axis+".png")
        print("\n")
# Out:
# Max Temp vs Lat. plotting...
#              *Max Temp vs Lat. saved as ...output_data/Lattitude_vs_Max Temp.png
#
#
# Humidity vs Lat. plotting...
#              *Humidity vs Lat. saved as ...output_data/Lattitude_vs_Humidity.png
#
#
# Cloudiness vs Lat. plotting...
#              *Cloudiness vs Lat. saved as ...output_data/Lattitude_vs_Cloudiness.png
#
#
# Wind Speed vs Lat. plotting...
#              *Wind Speed vs Lat. saved as ...output_data/Lattitude_vs_Wind Speed.png
